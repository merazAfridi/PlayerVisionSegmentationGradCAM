jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/144.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/110.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/413.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/407.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/325.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/437.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/385.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/475.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/471.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/63.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/398.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/162.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/231.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/19.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/201.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/303.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/87.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/47.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/282.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/93.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/470.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/170.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/428.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/324.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/457.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/14.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/18.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/175.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/268.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/345.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/316.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/226.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/462.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/116.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/78.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/320.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/367.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/433.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/266.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/245.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/335.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/460.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/232.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/108.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/49.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/203.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/66.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/298.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/306.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/395.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/423.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/307.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/129.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/2.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/205.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/422.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/133.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/304.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/315.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/134.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/249.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/213.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/431.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/461.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/136.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/454.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/364.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/90.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/25.jpg
# /kaggle/input/football-players-train-test/data/Trainset/masks/147.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/521.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/516.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/501.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/503.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/486.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/513.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/518.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/490.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/500.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/512.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/527.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/509.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/515.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/506.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/524.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/494.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/481.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/525.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/482.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/498.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/485.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/502.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/496.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/507.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/488.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/492.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/523.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/487.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/495.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/497.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/491.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/484.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/520.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/493.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/522.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/510.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/499.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/508.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/514.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/519.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/517.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/526.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/505.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/511.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/483.jpg
# /kaggle/input/football-players-train-test/data/Testset/images/504.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/521.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/516.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/501.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/503.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/486.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/513.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/518.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/490.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/500.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/512.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/527.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/509.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/515.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/506.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/524.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/494.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/481.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/525.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/482.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/498.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/485.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/502.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/496.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/507.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/488.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/492.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/523.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/487.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/495.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/497.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/491.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/484.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/520.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/493.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/522.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/510.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/499.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/508.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/514.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/519.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/517.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/526.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/505.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/511.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/483.jpg
# /kaggle/input/football-players-train-test/data/Testset/masks/504.jpg

# %%
# !pip install albumentations==1.2.1
# Out:
# Collecting albumentations==1.2.1
#   Downloading albumentations-1.2.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.2.1) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from albumentations==1.2.1) (1.13.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.2.1) (0.25.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.2.1) (6.0.2)
# Collecting qudida>=0.0.4 (from albumentations==1.2.1)
#   Downloading qudida-0.0.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.2.1) (4.10.0.84)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.11.1->albumentations==1.2.1) (2.4.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations==1.2.1) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations==1.2.1) (4.12.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (11.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.2.1) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.2.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.2.1) (3.5.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.11.1->albumentations==1.2.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.11.1->albumentations==1.2.1) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.11.1->albumentations==1.2.1) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.11.1->albumentations==1.2.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.11.1->albumentations==1.2.1) (2024.2.0)
# Downloading albumentations-1.2.1-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.7/116.7 kB 4.2 MB/s eta 0:00:00
# Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Installing collected packages: qudida, albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albumentations-1.2.1 qudida-0.0.4

# %%
# !pip install segmentation-models-pytorch
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting efficientnet-pytorch>=0.6.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.29.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (11.0.0)
# Collecting pretrainedmodels>=0.7.1 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.17.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.0.12)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (4.12.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2.4.1)
# Collecting munch (from pretrainedmodels>=0.7.1->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.9->segmentation-models-pytorch) (0.4.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation-models-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->segmentation-models-pytorch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation-models-pytorch) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->segmentation-models-pytorch) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 9.2 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16424 sha256=bd36b6dea64826f43f40975beeaf2af0f716573492a2c012cfe42ffa12577caa
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60944 sha256=ac226ce70e1a994941a15ebed61e74bcef13abfdeb278d9ca5bd428dcc8b5eba
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, pretrainedmodels, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.4.0

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
from albumentations.pytorch import ToTensorV2
import requests
import segmentation_models_pytorch as smp

# %%
train_image_dir = r'/kaggle/input/football-players-train-test/data/Trainset/images'
train_mask_dir  = r'/kaggle/input/football-players-train-test/data/Trainset/masks'
test_image_dir  = r'/kaggle/input/football-players-train-test/data/Testset/images'
test_mask_dir   = r'/kaggle/input/football-players-train-test/data/Testset/masks'

# %%
#creating Custom Dataset
class FootballDataset(Dataset):
    def __init__(self, image_dir, mask_dir, joint_transform=None):
        """
        Args:
            image_dir (str): Directory with images.
            mask_dir (str): Directory with masks.
            joint_transform (callable, optional): Augmentation/Preprocessing to apply jointly.
        """
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_names = sorted(os.listdir(image_dir))
        self.mask_names  = sorted(os.listdir(mask_dir))
        self.joint_transform = joint_transform

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_names[idx])
        mask_path  = os.path.join(self.mask_dir, self.mask_names[idx])
        image = Image.open(image_path).convert("RGB")
        mask  = Image.open(mask_path).convert("L")  #bnw mask

        #if joint transform provided;
        #then convert to NumPy array
        if self.joint_transform is not None:
            image_np = np.array(image)
            mask_np  = np.array(mask)
            augmented = self.joint_transform(image=image_np, mask=mask_np)
            image = augmented["image"]
            mask  = augmented["mask"]
            #ensurng mask has channel dim (1, H, W)
            if mask.ndim == 2:
                mask = mask.unsqueeze(0)
            #mask to float; scale to [0, 1]
            mask = mask.float() / 255.0
        return image, mask

# %% [markdown]
# **Augmentations / Preprocessing Transforms**

# %%
#augmentations / Preprocessing Transforms


#resize512x512
train_joint_transform = A.Compose([
    A.Resize(512, 512),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=15, p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
], additional_targets={'mask': 'mask'})

#Val set,only resize and normalize (no random aug)
val_joint_transform = A.Compose([
    A.Resize(512, 512),
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
], additional_targets={'mask': 'mask'})

#test set same transform as val
test_joint_transform = val_joint_transform


#creating dataset Instances & split it

#creatinfg full dataset for training folder
#using training transforms
full_dataset = FootballDataset(train_image_dir, train_mask_dir, joint_transform=train_joint_transform)

#pplit 90% train, 10% val
total_samples = len(full_dataset)
split_index = int(0.9 * total_samples)
indices = list(range(total_samples))
train_indices = indices[:split_index]
val_indices   = indices[split_index:]

#For val,, creating separate dataset with val transform
full_dataset_val = FootballDataset(train_image_dir, train_mask_dir, joint_transform=val_joint_transform)

#creating subset objects for train and val
train_subset = Subset(full_dataset, train_indices)
val_subset   = Subset(full_dataset_val, val_indices)

#dataLoaders with batch size eight
train_loader = DataLoader(train_subset, batch_size=8, shuffle=True, num_workers=2)
val_loader   = DataLoader(val_subset, batch_size=8, shuffle=False, num_workers=2)

#create test dataset & loader
test_dataset = FootballDataset(test_image_dir, test_mask_dir, joint_transform=test_joint_transform)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
#Visualize training
sample_image, sample_mask = full_dataset[0]
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(np.transpose(sample_image.cpu().numpy(), (1, 2, 0)))
plt.title("Augmented & Resized Image (512x512)")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(sample_mask.squeeze(), cmap='gray')
plt.title("Mask (512x512)")
plt.axis('off')
plt.show()

# %% [markdown]
# **Evaluation Metrics (Dice Coef, jaccard Index, Pixel accuracy)**

# %%
#evaluation Metrics

def dice_coef(pred, target, smooth=1.):
    pred = torch.sigmoid(pred)
    pred = (pred > 0.5).float()
    intersection = (pred * target).sum(dim=(2, 3))
    union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3))
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice.mean()

def jaccard_index(pred, target, smooth=1.):
    pred = torch.sigmoid(pred)
    pred = (pred > 0.5).float()
    intersection = (pred * target).sum(dim=(2, 3))
    union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return jaccard.mean()

def pixel_accuracy(pred, target):
    pred = torch.sigmoid(pred)
    pred = (pred > 0.5).float()
    correct = (pred == target).float()
    return correct.sum() / correct.numel()

# %% [markdown]
# **Define Models , Loss, Optimizer**

# %%
#UNet with ResNet50 Encoder

model = smp.Unet(
    encoder_name="resnet50",
    encoder_weights="imagenet",
    in_channels=3,                     #RGB images
    classes=1,                         # binary seg output
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)


# Loss, Optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 208MB/s]

# %% [markdown]
# **Training**

# %%
import os
import time
import torch

#directory to save model
checkpoint_dir = '/kaggle/working/checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

num_epochs = 50
total_training_time = 0.0

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_dices = []
val_dices = []
train_jaccards = []
val_jaccards = []

for epoch in range(num_epochs):
    epoch_start_time = time.time()

    #train
    model.train()
    train_loss = 0.0
    train_dice = 0.0
    train_jaccard = 0.0
    train_acc = 0.0
    n_train_batches = 0

    for images, masks in train_loader:
        images = images.to(device)
        masks = masks.to(device)  #shape= [B, 1, 512, 512] with values in [0,1]

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_dice += dice_coef(outputs, masks).item()
        train_jaccard += jaccard_index(outputs, masks).item()
        train_acc += pixel_accuracy(outputs, masks).item()
        n_train_batches += 1

    train_loss /= n_train_batches
    train_dice /= n_train_batches
    train_jaccard /= n_train_batches
    train_acc /= n_train_batches

    #Val
    model.eval()
    val_loss = 0.0
    val_dice = 0.0
    val_jaccard = 0.0
    val_acc = 0.0
    n_val_batches = 0

    with torch.no_grad():
        for images, masks in val_loader:
            images = images.to(device)
            masks = masks.to(device)

            outputs = model(images)
            loss = criterion(outputs, masks)

            val_loss += loss.item()
            val_dice += dice_coef(outputs, masks).item()
            val_jaccard += jaccard_index(outputs, masks).item()
            val_acc += pixel_accuracy(outputs, masks).item()
            n_val_batches += 1

    val_loss /= n_val_batches
    val_dice /= n_val_batches
    val_jaccard /= n_val_batches
    val_acc /= n_val_batches

    epoch_time = time.time() - epoch_start_time
    total_training_time += epoch_time

    #append metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    train_dices.append(train_dice)
    val_dices.append(val_dice)
    train_jaccards.append(train_jaccard)
    val_jaccards.append(val_jaccard)


    print(f"Epoch [{epoch+1}/{num_epochs}] - "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Train Dice: {train_dice:.4f}, Train Jaccard: {train_jaccard:.4f} | "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val Dice: {val_dice:.4f}, Val Jaccard: {val_jaccard:.4f} | "
          f"Time: {epoch_time:.2f}s")

#save model
checkpoint_path = os.path.join(checkpoint_dir, 'Unet_ResNet50.pth')
torch.save({
    'epoch': num_epochs,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss': train_loss,
    'val_loss': val_loss,
    'train_dice': train_dice,
    'val_dice': val_dice,
    'train_jaccard': train_jaccard,
    'val_jaccard': val_jaccard,
    'train_acc': train_acc,
    'val_acc': val_acc
}, checkpoint_path)

print(f"Final model checkpoint saved at {checkpoint_path}")
print(f"Total Training Time: {total_training_time:.2f}s")
# Out:
# Epoch [1/50] - Train Loss: 0.5166, Train Acc: 0.8349, Train Dice: 0.3121, Train Jaccard: 0.2004 | Val Loss: 0.3351, Val Acc: 0.9629, Val Dice: 0.5653, Val Jaccard: 0.3965 | Time: 37.24s
# Epoch [2/50] - Train Loss: 0.2928, Train Acc: 0.9692, Train Dice: 0.7286, Train Jaccard: 0.5770 | Val Loss: 0.2445, Val Acc: 0.9755, Val Dice: 0.7744, Val Jaccard: 0.6331 | Time: 38.19s
# Epoch [3/50] - Train Loss: 0.2338, Train Acc: 0.9714, Train Dice: 0.7716, Train Jaccard: 0.6310 | Val Loss: 0.2134, Val Acc: 0.9752, Val Dice: 0.7797, Val Jaccard: 0.6421 | Time: 42.40s
# Epoch [4/50] - Train Loss: 0.1860, Train Acc: 0.9725, Train Dice: 0.8047, Train Jaccard: 0.6748 | Val Loss: 0.1631, Val Acc: 0.9763, Val Dice: 0.8199, Val Jaccard: 0.6956 | Time: 43.66s
# Epoch [5/50] - Train Loss: 0.1489, Train Acc: 0.9730, Train Dice: 0.8211, Train Jaccard: 0.6975 | Val Loss: 0.1375, Val Acc: 0.9760, Val Dice: 0.8087, Val Jaccard: 0.6808 | Time: 42.55s
# Epoch [6/50] - Train Loss: 0.1207, Train Acc: 0.9733, Train Dice: 0.8344, Train Jaccard: 0.7167 | Val Loss: 0.1113, Val Acc: 0.9766, Val Dice: 0.8323, Val Jaccard: 0.7140 | Time: 43.30s
# Epoch [7/50] - Train Loss: 0.1012, Train Acc: 0.9735, Train Dice: 0.8424, Train Jaccard: 0.7285 | Val Loss: 0.1011, Val Acc: 0.9765, Val Dice: 0.8343, Val Jaccard: 0.7170 | Time: 42.66s
# Epoch [8/50] - Train Loss: 0.0877, Train Acc: 0.9736, Train Dice: 0.8444, Train Jaccard: 0.7317 | Val Loss: 0.0805, Val Acc: 0.9769, Val Dice: 0.8532, Val Jaccard: 0.7451 | Time: 43.16s
# Epoch [9/50] - Train Loss: 0.0759, Train Acc: 0.9738, Train Dice: 0.8532, Train Jaccard: 0.7449 | Val Loss: 0.0702, Val Acc: 0.9770, Val Dice: 0.8524, Val Jaccard: 0.7440 | Time: 43.16s
# Epoch [10/50] - Train Loss: 0.0658, Train Acc: 0.9740, Train Dice: 0.8617, Train Jaccard: 0.7577 | Val Loss: 0.0608, Val Acc: 0.9773, Val Dice: 0.8675, Val Jaccard: 0.7664 | Time: 43.15s
# Epoch [11/50] - Train Loss: 0.0586, Train Acc: 0.9740, Train Dice: 0.8659, Train Jaccard: 0.7640 | Val Loss: 0.0537, Val Acc: 0.9773, Val Dice: 0.8731, Val Jaccard: 0.7752 | Time: 43.06s
# Epoch [12/50] - Train Loss: 0.0520, Train Acc: 0.9742, Train Dice: 0.8707, Train Jaccard: 0.7714 | Val Loss: 0.0481, Val Acc: 0.9775, Val Dice: 0.8756, Val Jaccard: 0.7791 | Time: 43.01s
# Epoch [13/50] - Train Loss: 0.0469, Train Acc: 0.9743, Train Dice: 0.8747, Train Jaccard: 0.7778 | Val Loss: 0.0439, Val Acc: 0.9774, Val Dice: 0.8761, Val Jaccard: 0.7802 | Time: 43.03s
# Epoch [27/50] - Train Loss: 0.0198, Train Acc: 0.9747, Train Dice: 0.8965, Train Jaccard: 0.8127 | Val Loss: 0.0180, Val Acc: 0.9778, Val Dice: 0.9017, Val Jaccard: 0.8213 | Time: 43.22s
# Epoch [28/50] - Train Loss: 0.0190, Train Acc: 0.9747, Train Dice: 0.8983, Train Jaccard: 0.8157 | Val Loss: 0.0192, Val Acc: 0.9777, Val Dice: 0.8923, Val Jaccard: 0.8066 | Time: 42.97s
# Epoch [29/50] - Train Loss: 0.0183, Train Acc: 0.9748, Train Dice: 0.8981, Train Jaccard: 0.8155 | Val Loss: 0.0166, Val Acc: 0.9779, Val Dice: 0.9042, Val Jaccard: 0.8254 | Time: 42.85s
# Epoch [30/50] - Train Loss: 0.0178, Train Acc: 0.9748, Train Dice: 0.8986, Train Jaccard: 0.8162 | Val Loss: 0.0162, Val Acc: 0.9779, Val Dice: 0.9033, Val Jaccard: 0.8238 | Time: 43.01s
# Epoch [31/50] - Train Loss: 0.0172, Train Acc: 0.9749, Train Dice: 0.9000, Train Jaccard: 0.8185 | Val Loss: 0.0153, Val Acc: 0.9780, Val Dice: 0.9071, Val Jaccard: 0.8302 | Time: 43.16s
# Epoch [32/50] - Train Loss: 0.0167, Train Acc: 0.9749, Train Dice: 0.9011, Train Jaccard: 0.8203 | Val Loss: 0.0150, Val Acc: 0.9780, Val Dice: 0.9068, Val Jaccard: 0.8297 | Time: 42.94s
# Epoch [33/50] - Train Loss: 0.0163, Train Acc: 0.9748, Train Dice: 0.9001, Train Jaccard: 0.8188 | Val Loss: 0.0145, Val Acc: 0.9780, Val Dice: 0.9065, Val Jaccard: 0.8292 | Time: 43.00s
# Epoch [34/50] - Train Loss: 0.0157, Train Acc: 0.9749, Train Dice: 0.9034, Train Jaccard: 0.8241 | Val Loss: 0.0143, Val Acc: 0.9780, Val Dice: 0.9077, Val Jaccard: 0.8312 | Time: 43.23s
# Epoch [35/50] - Train Loss: 0.0153, Train Acc: 0.9749, Train Dice: 0.9040, Train Jaccard: 0.8252 | Val Loss: 0.0141, Val Acc: 0.9780, Val Dice: 0.9057, Val Jaccard: 0.8279 | Time: 42.99s
# Epoch [36/50] - Train Loss: 0.0149, Train Acc: 0.9750, Train Dice: 0.9042, Train Jaccard: 0.8256 | Val Loss: 0.0134, Val Acc: 0.9780, Val Dice: 0.9104, Val Jaccard: 0.8357 | Time: 42.89s
# Epoch [37/50] - Train Loss: 0.0147, Train Acc: 0.9750, Train Dice: 0.9037, Train Jaccard: 0.8247 | Val Loss: 0.0133, Val Acc: 0.9780, Val Dice: 0.9074, Val Jaccard: 0.8309 | Time: 43.05s
# Epoch [38/50] - Train Loss: 0.0143, Train Acc: 0.9749, Train Dice: 0.9057, Train Jaccard: 0.8280 | Val Loss: 0.0129, Val Acc: 0.9780, Val Dice: 0.9097, Val Jaccard: 0.8346 | Time: 43.10s
# Epoch [39/50] - Train Loss: 0.0141, Train Acc: 0.9749, Train Dice: 0.9054, Train Jaccard: 0.8276 | Val Loss: 0.0128, Val Acc: 0.9780, Val Dice: 0.9090, Val Jaccard: 0.8335 | Time: 43.01s
# Epoch [40/50] - Train Loss: 0.0138, Train Acc: 0.9749, Train Dice: 0.9064, Train Jaccard: 0.8292 | Val Loss: 0.0129, Val Acc: 0.9780, Val Dice: 0.9081, Val Jaccard: 0.8321 | Time: 43.04s
# Epoch [41/50] - Train Loss: 0.0136, Train Acc: 0.9749, Train Dice: 0.9065, Train Jaccard: 0.8293 | Val Loss: 0.0121, Val Acc: 0.9781, Val Dice: 0.9120, Val Jaccard: 0.8385 | Time: 42.98s
# Epoch [42/50] - Train Loss: 0.0134, Train Acc: 0.9749, Train Dice: 0.9064, Train Jaccard: 0.8292 | Val Loss: 0.0120, Val Acc: 0.9781, Val Dice: 0.9104, Val Jaccard: 0.8358 | Time: 43.02s
# Epoch [43/50] - Train Loss: 0.0130, Train Acc: 0.9750, Train Dice: 0.9086, Train Jaccard: 0.8328 | Val Loss: 0.0115, Val Acc: 0.9781, Val Dice: 0.9128, Val Jaccard: 0.8397 | Time: 43.12s
# Epoch [44/50] - Train Loss: 0.0128, Train Acc: 0.9751, Train Dice: 0.9087, Train Jaccard: 0.8330 | Val Loss: 0.0114, Val Acc: 0.9781, Val Dice: 0.9142, Val Jaccard: 0.8422 | Time: 42.92s
# Epoch [45/50] - Train Loss: 0.0126, Train Acc: 0.9751, Train Dice: 0.9093, Train Jaccard: 0.8341 | Val Loss: 0.0112, Val Acc: 0.9781, Val Dice: 0.9143, Val Jaccard: 0.8423 | Time: 42.78s
# Epoch [46/50] - Train Loss: 0.0124, Train Acc: 0.9750, Train Dice: 0.9095, Train Jaccard: 0.8345 | Val Loss: 0.0110, Val Acc: 0.9781, Val Dice: 0.9142, Val Jaccard: 0.8421 | Time: 43.13s
# Epoch [47/50] - Train Loss: 0.0122, Train Acc: 0.9750, Train Dice: 0.9103, Train Jaccard: 0.8357 | Val Loss: 0.0112, Val Acc: 0.9781, Val Dice: 0.9096, Val Jaccard: 0.8344 | Time: 43.12s
# Epoch [48/50] - Train Loss: 0.0122, Train Acc: 0.9750, Train Dice: 0.9099, Train Jaccard: 0.8352 | Val Loss: 0.0108, Val Acc: 0.9781, Val Dice: 0.9154, Val Jaccard: 0.8442 | Time: 43.02s
# Epoch [49/50] - Train Loss: 0.0119, Train Acc: 0.9750, Train Dice: 0.9106, Train Jaccard: 0.8363 | Val Loss: 0.0106, Val Acc: 0.9781, Val Dice: 0.9158, Val Jaccard: 0.8449 | Time: 42.72s
# Epoch [50/50] - Train Loss: 0.0117, Train Acc: 0.9751, Train Dice: 0.9119, Train Jaccard: 0.8383 | Val Loss: 0.0105, Val Acc: 0.9781, Val Dice: 0.9143, Val Jaccard: 0.8424 | Time: 42.81s
# Final model checkpoint saved at /kaggle/working/checkpoints/Unet_ResNet50.pth
# Total Training Time: 2139.47s

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 10))

#loss
plt.subplot(2, 2, 1)
plt.plot(epochs, train_losses, 'b', label='Training Loss')
plt.plot(epochs, val_losses, 'r', label='Val Loss')
plt.title('Training and Val Loss (Unet_ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

#accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, train_accuracies, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracies, 'r', label='Val Accuracy')
plt.title('Training and Val Accuracy (Unet_ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

#dice coefficient
plt.subplot(2, 2, 3)
plt.plot(epochs, train_dices, 'b', label='Training Dice')
plt.plot(epochs, val_dices, 'r', label='Val Dice')
plt.title('Training and Val Dice Coefficient (Unet_ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Dice Coefficient')
plt.legend()

#jaccard index
plt.subplot(2, 2, 4)
plt.plot(epochs, train_jaccards, 'b', label='Training Jaccard')
plt.plot(epochs, val_jaccards, 'r', label='Val Jaccard')
plt.title('Training and Val Jaccard Index (Unet_ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Jaccard Index')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Evaluation on Test Set**

# %%
#evaluate on Test Set
model.eval()
test_loss = 0.0
test_acc = 0.0
test_dice = 0.0
test_jaccard = 0.0
n_test_batches = 0

with torch.no_grad():
    for images, masks in test_loader:
        images = images.to(device)
        masks = masks.to(device)

        outputs = model(images)
        loss = criterion(outputs, masks)

        test_loss += loss.item()
        test_dice += dice_coef(outputs, masks).item()
        test_jaccard += jaccard_index(outputs, masks).item()
        test_acc += pixel_accuracy(outputs, masks).item()
        n_test_batches += 1

test_loss /= n_test_batches
test_dice /= n_test_batches
test_jaccard /= n_test_batches
test_acc /= n_test_batches

print("Test Evaluation (Unet_ResNet50)")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Dice: {test_dice:.4f}")
print(f"Test Jaccard: {test_jaccard:.4f}")
# Out:
# Test Evaluation (Unet_ResNet50)
# Test Loss: 0.0111
# Test Accuracy: 0.9736
# Test Dice: 0.9277
# Test Jaccard: 0.8652

# %% [markdown]
# **Evaluate on external Image**

# %%
#external image (Download, Resize, Predict)
image_url = "https://cdn.images.express.co.uk/img/dynamic/67/590x/England-vs-Colombia-time-983344.jpg"
response = requests.get(image_url)
ext_image = Image.open(BytesIO(response.content)).convert("RGB")

ext_image_resized = ext_image.resize((512, 512))


#preprocess same as val
ext_image_np = np.array(ext_image_resized)
#for dummy mask, we can pass the same image
#it won't use
processed = val_joint_transform(image=ext_image_np, mask=ext_image_np)
input_image = processed["image"].unsqueeze(0).to(device)  #add batch dim


model.eval()
with torch.no_grad():
    output = model(input_image)
    pred_mask = torch.sigmoid(output)
    pred_mask = (pred_mask > 0.5).float().cpu().squeeze()

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(ext_image_resized)
plt.title("External Football Player Image (512x512)")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(pred_mask, cmap="gray")
plt.title("Predicted Mask")
plt.axis('off')
plt.show()

# %% [markdown]
# **Grad CAM Heatmap**

# %%
pip install grad-cam
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.5.4.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 54.4 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from grad-cam) (11.0.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (0.20.1+cu121)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.67.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from grad-cam) (3.7.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->grad-cam) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->grad-cam) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->grad-cam) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->grad-cam) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->grad-cam) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->grad-cam) (2024.2.0)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.4-py3-none-any.whl size=39647 sha256=c72ddac41090c50738cda1e55f5a16689017782931f27a8a14248130575ab0c3
#   Stored in directory: /root/.cache/pip/wheels/50/b0/82/1f97b5348c7fe9f0ce0ba18497202cafa5dec4562bd5292680
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.5.4 ttach-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install grad-cam
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget


#GradCAM
#external image as a NumPy array
#preprocess the external img using gradcam func
input_tensor_cam = preprocess_image(ext_image_np,
                                    mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])

#target layer
#for  U-Net with a ResNet50 encoder,using the last block of layer4.
target_layer = model.encoder.layer4[-1]  #adjust layer

#initialize GradCAM
cam = GradCAM(model=model, target_layers=[target_layer])


#since the output for single sample is likely shape (1, H, W)
#we simply take its mean
targets = [lambda output: output.mean()]

#gen Grad-CAM
grayscale_cam = cam(input_tensor=input_tensor_cam, targets=targets)[0]

visualization = show_cam_on_image(ext_image_np.astype(np.float32) / 255.0,
                                  grayscale_cam,
                                  use_rgb=True)

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
axes[0].imshow(ext_image_resized)
axes[0].set_title("External Image (512x512)")
axes[0].axis("off")


axes[1].imshow(pred_mask, cmap="gray")
axes[1].set_title("Predicted Mask (Unet_ResNet50)")
axes[1].axis("off")


axes[2].imshow(visualization)
axes[2].set_title("Grad-CAM Heatmap (Unet_ResNet50)")
axes[2].axis("off")

plt.show()

# %% [markdown]
# **Grad CAM Analysis on Test Sample**

# %%
#get one batch from test_loader,pick the 1st sample
test_iter = iter(test_loader)
test_images, test_masks = next(test_iter)

input_image_test = test_images[0:1].to(device)

#denormalize the test img for visualization
# since normalization was applied using mean=[0.485, 0.456, 0.406] , std=[0.229, 0.224, 0.225])
mean = [0.485, 0.456, 0.406]
std  = [0.229, 0.224, 0.225]
denorm_img = input_image_test[0].cpu().clone()
for t, m, s in zip(denorm_img, mean, std):
    t.mul_(s).add_(m)
denorm_img_np = denorm_img.clamp(0, 1).permute(1, 2, 0).numpy()  # shape: (H, W, C)


target_layer = model.encoder.layer4[-1] #Adjust which layer


from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
cam = GradCAM(model=model, target_layers=[target_layer])

targets = [lambda output: output.mean()]

grayscale_cam = cam(input_tensor=input_image_test, targets=targets)[0]


visualization = show_cam_on_image(denorm_img_np.astype(np.float32),
                                  grayscale_cam,
                                  use_rgb=True)


model.eval()
with torch.no_grad():
    output_test = model(input_image_test)
    pred_mask_test = torch.sigmoid(output_test)
    pred_mask_test = (pred_mask_test > 0.5).float().cpu().squeeze()


import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
axes[0].imshow(denorm_img_np)
axes[0].set_title("Test Image (De-Normalized)")
axes[0].axis("off")

axes[1].imshow(pred_mask_test, cmap="gray")
axes[1].set_title("Predicted Mask (Unet_ResNet50)")
axes[1].axis("off")

axes[2].imshow(visualization)
axes[2].set_title("Grad-CAM Heatmap (Unet_ResNet50)")
axes[2].axis("off")

plt.show()

# %%
import torch
#load csaved model
checkpoint_path = '/kaggle/working/checkpoints/Unet_ResNet50.pth'
checkpoint = torch.load(checkpoint_path)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# <ipython-input-31-03f2f6f57e1c>:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(3072, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
import torch


save_path = '/kaggle/working/Unet_resnet50.pth'


torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': epoch,
    'train_loss': train_loss,
    'val_loss': val_loss,
    'train_acc': train_acc,
    'val_acc': val_acc,
    'train_dice': train_dice,
    'val_dice': val_dice,
    'train_jaccard': train_jaccard,
    'val_jaccard': val_jaccard,
}, save_path)

print(f"Model and metrics saved at {save_path}")
# Out:
# Model and metrics saved at /kaggle/working/Unet_resnet50.pth
